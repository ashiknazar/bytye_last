# %% [markdown]
# - i created project `bytye_last` in github and cloned it to my pc , created folders (agent,backend,docker,frontend,ingestion,processing) and file docker-compose.yml. i pushed to github, then i created 2 branch dev,feature/login in git .
